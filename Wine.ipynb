# %% [markdown]
# ## Importing Libraries

# %%
import pandas as pd
# %matplotlib inline
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## Reading the CSV File

# %%
df = pd.read_csv('WineQT.csv')
df
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4             0.700         0.00             1.9      0.076
# 1               7.8             0.880         0.00             2.6      0.098
# 2               7.8             0.760         0.04             2.3      0.092
# 3              11.2             0.280         0.56             1.9      0.075
# 4               7.4             0.700         0.00             1.9      0.076
# ...             ...               ...          ...             ...        ...
# 1138            6.3             0.510         0.13             2.3      0.076
# 1139            6.8             0.620         0.08             1.9      0.068
# 1140            6.2             0.600         0.08             2.0      0.090
# 1141            5.9             0.550         0.10             2.2      0.062
# 1142            5.9             0.645         0.12             2.0      0.075
#
# ...

# %% [markdown]
# ### Information about the Dataset.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1143 entries, 0 to 1142
# Data columns (total 13 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   fixed acidity         1143 non-null   float64
#  1   volatile acidity      1143 non-null   float64
#  2   citric acid           1143 non-null   float64
#  3   residual sugar        1143 non-null   float64
#  4   chlorides             1143 non-null   float64
#  5   free sulfur dioxide   1143 non-null   float64
#  6   total sulfur dioxide  1143 non-null   float64
#  7   density               1143 non-null   float64
#  8   pH                    1143 non-null   float64
#  9   sulphates             1143 non-null   float64
#  10  alcohol               1143 non-null   float64
#  11  quality               1143 non-null   int64
#  12  Id                    1143 non-null   int64
# dtypes: float64(11), int64(2)
# memory usage: 116.2 KB

# %% [markdown]
# ### Checking for duplicate values

# %%
df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# ### Checking for null values

# %%
df.isna().any()
# Out:
# fixed acidity           False
# volatile acidity        False
# citric acid             False
# residual sugar          False
# chlorides               False
# free sulfur dioxide     False
# total sulfur dioxide    False
# density                 False
# pH                      False
# sulphates               False
# alcohol                 False
# quality                 False
# Id                      False
# dtype: bool

# %% [markdown]
# ### Descriptive Statistics of the Dataset

# %%
df.describe()
# Out:
#        fixed acidity  volatile acidity  citric acid  residual sugar  \
# count    1143.000000       1143.000000  1143.000000     1143.000000
# mean        8.311111          0.531339     0.268364        2.532152
# std         1.747595          0.179633     0.196686        1.355917
# min         4.600000          0.120000     0.000000        0.900000
# 25%         7.100000          0.392500     0.090000        1.900000
# 50%         7.900000          0.520000     0.250000        2.200000
# 75%         9.100000          0.640000     0.420000        2.600000
# max        15.900000          1.580000     1.000000       15.500000
#
#          chlorides  free sulfur dioxide  total sulfur dioxide      density  \
# count  1143.000000          1143.000000           1143.000000  1143.000000
# mean      0.086933            15.615486             45.914698     0.996730
# std       0.047267            10.250486             32.782130     0.001925
# ...

# %%
plt.bar(df['quality'],df['alcohol'])
plt.xlabel('Quality')
plt.ylabel("Alcohol")
plt.show()

# %% [markdown]
# ### Correlation among all Features

# %%
plt.figure(figsize = (13,13))
sns.heatmap(df.corr(),annot = True)
# Out:
# <Axes: >

# %% [markdown]
# ### How many Types of Quality?

# %%
df['quality'].unique()
# Out:
# array([5, 6, 7, 4, 8, 3], dtype=int64)

# %% [markdown]
# There are 6 types of alcohol quality.

# %% [markdown]
# ### Avg. Volatile Acidity per Quality

# %%
ax = df.groupby('quality')['volatile acidity'].mean().plot(kind = 'bar')
ax.bar_label(ax.containers[0])
plt.xlabel('Quality of Alcohol')
plt.ylabel("Avg. Volatile Acidity")
plt.title("Avg. Volatile Acidity per Quality")
plt.show()

# %% [markdown]
# From the above we can observe that Avg. volatile acidity decreases as quality increases, as in last there is very small diffrence.

# %% [markdown]
# ### Avg. Citric Acid per Quality

# %%
ax = df.groupby('quality')['citric acid'].mean().plot(kind = 'bar')
ax.bar_label(ax.containers[0])
plt.xlabel('Quality of Alcohol')
plt.ylabel("Avg. Citric Acid")
plt.title("Avg. Citric Acid per Quality")
plt.show()

# %% [markdown]
# As quality of alcohol is increasing the avg.citric acid is also increasing.

# %% [markdown]
# ### Lingraph of pH and Quality

# %%
a = df.groupby('quality')['pH'].mean()
plt.plot(a.index, a.values, marker='o', linestyle='-', label='Mean pH')
plt.xlabel("Quality of wine")
plt.ylabel("Avg pH")
plt.title("Avg. pH of wine per quality")
plt.show()

# %% [markdown]
# Here in starting it has a zig zag pattern at last it decreases.

# %% [markdown]
# ### Histogram

# %%
df.hist(bins=100, figsize=(18,12))
plt.show()

# %% [markdown]
# ### Avg. residul sugar per quality

# %%
a = df.groupby('quality')['residual sugar'].mean()
plt.plot(a.index, a.values, marker='o', linestyle='-', label='Mean residual sugar',color = 'red')
plt.xlabel("Quality of wine")
plt.ylabel("Avg residual sugar")
plt.title("Avg. residul sugar per quality")
plt.show()

# %% [markdown]
# ### Moving to Machine Learning Part

# %%
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix, classification_report, accuracy_score, ConfusionMatrixDisplay
from sklearn.preprocessing import StandardScaler
from sklearn.ensemble import RandomForestClassifier

# %%
df['quality'] = df.quality.apply(lambda x:1 if x>=7 else 0)

# %%
x = df.drop('quality', axis=1)
y = df['quality']

# %% [markdown]
# ### Training and Testing the Data

# %%
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size = 0.3,random_state = 42)

# %%
x_train.shape
# Out:
# (800, 12)

# %%
x_test.shape
# Out:
# (343, 12)

# %% [markdown]
# ### Using Random Forest Classifier

# %%
rf = RandomForestClassifier()
rf.fit(x_train, y_train)
rf_pred = rf.predict(x_test)
rf_acc = accuracy_score(rf_pred, y_test)
print("Test accuracy: {:.2f}%".format(rf_acc*100))
# Out:
# Test accuracy: 90.09%

# %% [markdown]
# ### Classification Report

# %%
print(classification_report(y_test, rf_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.93      0.96      0.94       298
#            1       0.66      0.51      0.57        45
#
#     accuracy                           0.90       343
#    macro avg       0.79      0.74      0.76       343
# weighted avg       0.89      0.90      0.90       343

# %% [markdown]
# ### Confusion Matrix

# %%
from matplotlib import style
style.use('classic')
cm = confusion_matrix(y_test, rf_pred, labels=rf.classes_)
disp = ConfusionMatrixDisplay(confusion_matrix= cm, display_labels=rf.classes_)
disp.plot()
print("TN: ", cm[0][0])
print("FN: ", cm[1][0])
print("TP: ", cm[1][1])
print("FP: ", cm[0][1])
# Out:
# TN:  286
# FN:  22
# TP:  23
# FP:  12

# %% [markdown]
# ### Using SVC

# %%
from sklearn.svm import SVC
model = SVC()
model.fit(x_train,y_train)
pred_y = model.predict(x_test)
print("Accuracy Score:",accuracy_score(y_test,pred_y)*100)
# Out:
# Accuracy Score: 86.88046647230321

# %% [markdown]
# ### Using Stochastic Gradient Descent Classifier

# %%
from sklearn.linear_model import SGDClassifier
sgd = SGDClassifier(penalty = None)
sgd.fit(x_train, y_train)
pred_sgd = sgd.predict(x_test)

# %% [markdown]
# ### Classification Report

# %%
print(classification_report(y_test, pred_sgd))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.87      0.93      0.90       298
#            1       0.09      0.04      0.06        45
#
#     accuracy                           0.81       343
#    macro avg       0.48      0.49      0.48       343
# weighted avg       0.76      0.81      0.79       343

# %% [markdown]
# ### Confusion Matrix

# %%
from matplotlib import style
style.use('classic')
cm = confusion_matrix(y_test, pred_sgd, labels=sgd.classes_)
disp = ConfusionMatrixDisplay(confusion_matrix= cm, display_labels=sgd.classes_)
disp.plot()
print("TN: ", cm[0][0])
print("FN: ", cm[1][0])
print("TP: ", cm[1][1])
print("FP: ", cm[0][1])
# Out:
# TN:  277
# FN:  43
# TP:  2
# FP:  21
